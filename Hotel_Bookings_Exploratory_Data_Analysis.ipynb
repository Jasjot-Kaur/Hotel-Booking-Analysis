# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasjot-Kaur/Hotel-Booking-Analysis/blob/main/Hotel_Bookings_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ![Bellagio-Hotel-Casino-Las-Vegas.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Importing required Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Reading Data in Notebook**

# %%
#csv file location
file_location = '/content/drive/MyDrive/Alma Better/Capstone Projects/EDA 1/Hotel Booking Analysis - Jasjot Kaur/Hotel Bookings Data.csv'
#reading csv file
df_hotel = pd.read_csv(file_location)

# %% [markdown]
# **Exploring Dataset**

# %%
df_hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df_hotel.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# There are 32 columns and 119390 records in our dataframe

# %%
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df_hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# From the above information, we observe that there are null values present in 4 columns('children', 'country', 'agent' and 'company')

# %%
df_hotel.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ###***Comprehending the data:***

# %% [markdown]
# There are in total 32 colums with some unique values. Understanding these values will enable us a fruitful analysis of our dataframe!

# %%
# creating a copy of dataframe:
df_h = df_hotel.copy()

# %% [markdown]
# **Describing Columns:**
#
# ---

# %% [markdown]
# 1.   Hotel: Resort Hotel or City Hotel; string values
#
# 2.   is_canceled: Value indicating if the booking was canceled (1) or not (0); integer values
#
# 3.  lead_time: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date; integer values
#
# 4. arrival_date_year: Year of arrival date
#
# 5. arrival_date_month: Month of arrival date
#
# 6. arrival_date_week_number : Week number of year for arrival date
#
# 7. arrival_date_day_of_month : Day of arrival date
#
# 8. stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9. stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10. adults : Number of adults
#
# 11. children : Number of children
#
# 12. babies : Number of babies
#
# 13. meal : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# 14. country : Country of origin.`
#
# 15. market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 16. distribution_channel : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 17. is_repeated_guest : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# 18. previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. reserved_room_type : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# 21. assigned_room_type : Code for the type of room assigned to the booking.
#
# 22. booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# 23. deposit_type : Indication on if the customer made a deposit to guarantee the booking.
#
# 24. agent : ID of the travel agency that made the booking
#
# 25. company : ID of the company/entity that made the booking or responsible for paying the booking.
#
# 26. days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# 27. customer_type : Type of booking, assuming one of four categories
# 28. adr : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. required_car_parking_spaces : Number of car parking spaces required by the customer
#
# 30. total_of_special_requests : Number of special requests made by the customer (e.g. twin bed or high floor)
#
# 31. reservation_status : Reservation last status, assuming one of three categories
# 32. reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ##**DATA CLEANING**
#
# ##### ***Step 1:*** Remove duplicate or irrelevant observations
#
# #####***Step 2:*** Fix structural errors
#
# #####***Step 3:*** Round off integer values in dataframe
#
# #####***Step 4:*** Change data type as per requirement
#
# #####***Step 5:*** Adding new columns as per requirement

# %% [markdown]
# **Step 1: Remove duplicate, null or irrelevant observations**
#
# ---

# %%
# Replacing null values:
df_h["children"].replace(np.nan, 0, inplace=True)
df_h['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3.])

# %%
df_h['country'].replace(np.nan, "others", inplace=True)
df_h['country']
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 119390, dtype: object

# %%
df_h["agent"].replace(np.nan, 0, inplace=True)
df_h['agent'].unique()
# Out:
# array([  0., 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
df_h['company'].replace(np.nan, 0, inplace=True)
df_h['company'].unique()
# Out:
# array([  0., 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
df_h.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
df_h1 = df_h.drop_duplicates()

# %%
df_h1.shape
# Out:
# (87396, 32)

# %% [markdown]
# ***Removed Null Values and Duplicate Values***

# %%
df_h1.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# **Step 2: Fix structural errors**
#
# ---

# %%
# Renamed 2 Columns: to make the col names meaningful
df_h1 = df_h1.rename(columns={'is_canceled': 'Cancelled', 'is_repeated_guest': 'repeated_guest'})

# %%
df_h1.head()
# Out:
#           hotel  Cancelled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel          0        342               2015               July
# 1  Resort Hotel          0        737               2015               July
# 2  Resort Hotel          0          7               2015               July
# 3  Resort Hotel          0         13               2015               July
# 4  Resort Hotel          0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df_h1.describe()
# Out:
#           Cancelled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# **Step3: Round off integer values in dataframe**

# %%
df_h1.describe().round(2)
# Out:
#        Cancelled  lead_time  arrival_date_year  arrival_date_week_number  \
# count   87396.00   87396.00           87396.00                  87396.00
# mean        0.27      79.89            2016.21                     26.84
# std         0.45      86.05               0.69                     13.67
# min         0.00       0.00            2015.00                      1.00
# 25%         0.00      11.00            2016.00                     16.00
# 50%         0.00      49.00            2016.00                     27.00
# 75%         1.00     125.00            2017.00                     37.00
# max         1.00     737.00            2017.00                     53.00
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                   87396.00                 87396.00
# mean                       15.82                     1.01
# std                         8.84                     1.03
# min                         1.00                     0.00
# ...

# %% [markdown]
# **Step 4: Change data type as per requirement**

# %%
df_h1[['children', 'company', 'agent']] = df_h1[['children', 'company', 'agent']].astype('int64')

# %% [markdown]
# Datatype changed

# %%
df_h1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   Cancelled                       87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# **Step 5: Adding new columns as per requirement**

# %%
df_h1['total_people'] = df_h1['adults']+df_h1['children']+df_h1['babies']

# %%
df_h1['total_stay'] = df_h1['stays_in_weekend_nights']+df_h1['stays_in_week_nights']

# %% [markdown]
# ###**Our data is clean! We can now start analysising**

# %% [markdown]
# ##**Questions for Analysis**
# ___

# %% [markdown]
# 1. Which type of hotel is mostly prefered by the guests?
# 2. Which type of meal is mostly preferred by the guests?
# 3. Which Agent made the most bookings?
# 4. In which month most of the bookings happened?
# 5. Which Hotels has the most repeated guests?
# 6. Which Hotel type has the highest ADR?
# 7. From which country the most guests are coming?
# 8. What is the Percentage of repeated guests?
# 9. Which Market Segment has the higest cancellation rate?
# 10. What is the pecentage of cancellation for each hotel?

# %% [markdown]
#  **1.) Which type of hotel is mostly prefered by the guests?**

# %%
df_h1['hotel'].value_counts()
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df_h1['hotel'])
plt.xlabel('hotel')
plt.ylabel('Count')
plt.title("Preferred Hotel Type")
# Out:
# Text(0.5, 1.0, 'Preferred Hotel Type')

# %% [markdown]
# ***City Hotel is mostly prefered by guest***

# %% [markdown]
# ####**2.) Which type of meal is mostly preferred by the guests?**

# %%
df_h1['meal'].value_counts()
# Out:
# BB           67978
# SC            9481
# HB            9085
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
df_h1['meal'].value_counts().plot.pie(explode=[.05,.06,.07,.05,1], autopct='%1.1f%%', shadow=False, figsize=(15,15),fontsize=20)
plt.title("Most Preferred meal type")
# Out:
# Text(0.5, 1.0, 'Most Preferred meal type')

# %% [markdown]
# ***BB is the most prefered meal type***

# %% [markdown]
# ####**3.) Which are the top 5 Agents making most of the bookings?**

# %%
highest_bookings= df_h1.groupby(['agent'])['agent'].agg({'count'}).reset_index().sort_values(by='count',ascending=False)
print(highest_bookings)
# Out:
#      agent  count
# 9        9  28759
# 174    240  13028
# 0        0  12193
# 14      14   3349
# 7        7   3300
# ..     ...    ...
# 213    295      1
# 193    265      1
# 161    213      1
# 299    444      1
# 300    446      1
#
# [334 rows x 2 columns]

# %%
top_five_highest_bookings=highest_bookings[:5]
print(top_five_highest_bookings)
# Out:
#      agent  count
# 9        9  28759
# 174    240  13028
# 0        0  12193
# 14      14   3349
# 7        7   3300

# %%
plt.figure(figsize=(18,8))
sns.barplot(x=top_five_highest_bookings['agent'],y=top_five_highest_bookings['count'],order=top_five_highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Bookings Made by the Top 5 Agents")
# Out:
# Text(0.5, 1.0, 'Bookings Made by the Top 5 Agents')

# %% [markdown]
# ***Agent 9 was found to have made most of the bookings***

# %% [markdown]
# ####**4.) In which month most of the bookings happened?**

# %%
df_h1['arrival_date_month'].value_counts()
# Out:
# August       11257
# July         10057
# May           8355
# April         7908
# June          7765
# March         7513
# October       6934
# September     6690
# February      6098
# December      5131
# November      4995
# January       4693
# Name: arrival_date_month, dtype: int64

# %%
Monthly_bookings=df_h1.groupby(['arrival_date_month'])['arrival_date_month'].agg({'count'}).reset_index()
print(Monthly_bookings)
# Out:
#    arrival_date_month  count
# 0               April   7908
# 1              August  11257
# 2            December   5131
# 3            February   6098
# 4             January   4693
# 5                July  10057
# 6                June   7765
# 7               March   7513
# 8                 May   8355
# 9            November   4995
# 10            October   6934
# 11          September   6690

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df_h1['arrival_date_month'])
plt.xlabel('arrival_date_month')
plt.ylabel('Count')
plt.title("Monthly Bookings")
# Out:
# Text(0.5, 1.0, 'Monthly Bookings')

# %% [markdown]
# ***August month has the higest bookings***

# %% [markdown]
# ####**5.) Which hotel has the most repeated guests?**

# %%
vi=df_h1[df_h1['repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repeated_guests'})
print(vineet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-1c0976ccac08> in <module>()
#       1 vi=df_h1[df_h1['repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repeated_guests'})
# ----> 2 print(vineet)
#
# NameError: name 'vineet' is not defined

# %%
#set plot size adn plot barplot
plt.figure(figsize=(5,5))
sns.barplot(x=vi['hotel'],y=vi['number_of_repated_guests'])

# set labels
plt.xlabel('Hotel type')
plt.ylabel('count of repeated guests')
plt.title("Most repeated guests for each hotel")

# %% [markdown]
# ***It was found that City hotel had more repeated guest than Resort hotel by 1 guest***

# %% [markdown]
# ####**6.) Which hotel type has the highest ADR?**

# %%
#grouping by hotel adr
df_h1['hotel'].value_counts().plot.pie(explode=[.01,.01], autopct='%1.1f%%', shadow=False, figsize=(15,15),fontsize=20).patch.set_facecolor('white')
plt.title("Hotel type with highest ADR")

my_circle=plt.Circle( (0,0), 0.7, color='white')
 
# Pieplot + circle on it
#plt.pie(size, labels=names)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# ***City hotel has the highest ADR***

# %% [markdown]
# ####**7.) Which country are most of the guests from?**

# %%
pa=df_h1['country'].value_counts().reset_index()[:5].rename(columns={'index':'country', 'country' : 'number_of_guest' })
print(pa)

# %%
plt.figure(figsize=(18,8))
sns.barplot(x=pa['country'],y=pa['number_of_guest'])
plt.xlabel('country')
plt.ylabel('Number of Guest')
plt.title("Numbder of guest from different countries")

# %% [markdown]
# ***Most of the guests are from PRT country***

# %% [markdown]
# ####**8.) What is the Percentage of repeated guests?**

# %%
df_h1['repeated_guest'].value_counts()

# %%
df_h1['repeated_guest'].value_counts().plot.pie(explode=[.05,.05], autopct='%1.1f%%', shadow=False, figsize=(7,7),fontsize=20)
plt.title("Percentage of repeated guest")

# %% [markdown]
# ***Percentage of repeated guest is very low (3.9 %)***

# %% [markdown]
# ####**9.) Which Market Segment has the highest cancellation rate?**

# %%
segment = df_h1[df_h1['Cancelled'] == 1]
segment = segment.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   

segment

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='market_segment',y='counts',hue="hotel",data=segment)

plt.xlabel('Market segment')
plt.ylabel('Counts of Cancellation')
plt.title('Cancellation Rate Vs market_segment')

# %% [markdown]
# ***Online TA has the highest cancellation rate for both City and Resort hotels***

# %% [markdown]
# ####**10.) What is the percentage of hotel bookings cancellation?**

# %%
# How many guests have cancelled the hotel bookings
df_h1['Cancelled',0:'Canceled', 1:'Not Canceled'].value_counts()

# %%
# pie chart for cancellation and non-cancellation of bookings in each hotel type 
df_h1['Cancelled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Cancellation and non Cancellation")

# %% [markdown]
# ***72.5% of the hotel bookings were cancelled***

# %% [markdown]
# ####**11.) What is the Cancellation Rate Vs Distribution Channel?**

# %%
canceled_df = df_h1[df_h1['Cancelled'] == 1]    # 1 = canceled

#group by distribution channel
canceled_df = canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})
# canceled_df['Percentage']=canceled_df['Counts']*100/df1[df1['Cancelled']==1][0]
canceled_df

#set plot size and plot barchart 
plt.figure(figsize=(12,8))
sns.barplot(x='Distribution_channel',y='Counts',hue="Hotel",data=canceled_df)

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs Distribution channel')

# %% [markdown]
# ***TA/TO has the highest cancellation rates for both City and Resort hotels***

# %% [markdown]
# ####**12.) What is the Cancellation Rate Vs market_segment?**

# %%
market_segment_df=df_h1[df_h1['Cancelled']==1]   # canceled=1
market_segment_df
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by

market_segment_df

#set plotsizde and plot barchart
plt.figure(figsize=(20,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)

# set labels
plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs market_segment')

# %% [markdown]
# ***Online TA has the highest cancellation rates for both City and Reesort hotels***

# %% [markdown]
# ####**13.) What is the %  of not getting the same room vs Booking cancellation?**

# %%
# Define a function for the reserved room type is same  or not as  assigned room type
def same_room_allotment(x):
  '''function to check whether the reserved room 
  type is same  or not as  assigned room type'''

  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0


# create new column to df1
df_h1['Same_room_alloted_or_not']=df_h1.apply(lambda x: same_room_allotment(x),axis=1)

#groupby is canceled
grp_by_canceled_df=df_h1.groupby('Cancelled')

# create DF and calculate percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:"percentage"})
DF

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x=DF.index,y=DF['percentage'])

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('Cancelled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','Cancelled'])

# %% [markdown]
# ***2.5% bookings were cancelled beacuse of not getting the same room that was reserved***

# %% [markdown]
# ####**14.) What is the waiting time for each hotel type?**

# %%
#grouping by hotel and taking mean of days in waiting list
waiting_time_df=df_h1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
# waiting_time_df

#set the plot size
plt.figure(figsize=(10,8))

# plot barchart
sns.barplot(x=waiting_time_df['hotel'],y=waiting_time_df['days_in_waiting_list'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('waiting time (days)')
plt.title("Waiting time for each hotel type")

# %% [markdown]
# ***City hotel was found to have higher waiting time than Resort hotel***

# %% [markdown]
# ####**Observing Correlation of the columns**

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df_h1.corr(),annot=True)
plt.title('Co-relation of the columns')

# %% [markdown]
# **Observations**
#
# 1. Stay in week nights and total stay has strong correlation. This implies, mostly guests come to stay during week nights.
# 2. Required car parking and cancellations are negatively correlated, which means guest who require car parking usually do not cancel.
# 3. Repeated guest and previous bookings not cancelled have positive correlation, which means a repeated guest is not likely to cancel a booking.

# %% [markdown]
# # **Conclusions:**
#
# *   City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# *   27.5 % bookings were got cancelled out of all the bookings.
# *   Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
# *   The percentage of 0 changes made in the booking was more than 82 %. Percentage of Single changes made was about 10%.
# *   Most of the customers (91.6%) do not require car parking spaces.
# *   79.1 % bookings were made through TA/TO (travel agents/Tour operators).
# *   BB( Bed & Breakfast) is the most preferred type of meal by the guests.
# *   Maximum number of guests were from Portugal, i.e. more than 25000 guests.
# *   Most of the bookings for City hotels and Resort hotel were happened in 2016.
# *   Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels. The ADR was found higher for City Hotel (61.1%) and for resort hotel it was 38.9%.
# *   Booking cancellation rate is high for City hotels which almost 30 %.
# *   Average lead time for resort hotel is high.
# *   Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
# *   Resort hotels have the most repeated guests.
# *   Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
# *   Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.
# *   More than 2500 guests from Portugal country booked the hotels, followed by GBR (~10000) and the least guests were from BEL, BRA and NLD.
